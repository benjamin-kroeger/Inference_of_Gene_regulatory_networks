# %%
cd /home/benjaminkroeger/gene_regulatory_networks/data
# Out:
# /home/benjaminkroeger/gene_regulatory_networks/data

# %%
pwd
# Out:
# '/home/benjaminkroeger/gene_regulatory_networks/data'

# %%
import scanpy as sc

adata = sc.read_hdf('results_file.h5ad')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-62228c7ec6fd> in <module>
#       1 import scanpy as sc
#       2
# ----> 3 adata = sc.read_hdf('results_file.h5ad')
#
# TypeError: read_hdf() missing 1 required positional argument: 'key'

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2638 × 1838
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden'
#     var: 'gene_ids', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'hvg', 'leiden', 'leiden_colors', 'neighbors', 'pca', 'rank_genes_groups', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.umap(adata, color=['leiden'])

# %%
adata.obs['leiden']
# Out:
# AAACATACAACCAC-1    0
# AAACATTGAGCTAC-1    2
# AAACATTGATCAGC-1    0
# AAACCGTGCTTCCG-1    1
# AAACCGTGTATGCG-1    0
#                    ..
# TTTCGAACTCTCAT-1    1
# TTTCTACTGAGGCA-1    2
# TTTCTACTTCCTCG-1    2
# TTTGCATGAGAGGC-1    2
# TTTGCATGCCTCAC-1    0
# Name: leiden, Length: 2638, dtype: category
# Categories (4, object): [0, 1, 2, 3]

# %%
cluster0 = adata[adata.obs['leiden']=='0',:]
cluster1 = adata[adata.obs['leiden']=='1',:]

# %%
cluster0
# Out:
# View of AnnData object with n_obs × n_vars = 1614 × 1838
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden'
#     var: 'gene_ids', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'hvg', 'leiden', 'leiden_colors', 'neighbors', 'pca', 'rank_genes_groups', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
cluster1
# Out:
# View of AnnData object with n_obs × n_vars = 670 × 1838
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden'
#     var: 'gene_ids', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'hvg', 'leiden', 'leiden_colors', 'neighbors', 'pca', 'rank_genes_groups', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.umap(cluster0, color=['leiden'])
sc.pl.umap(cluster1, color=['leiden'])

# %%
cluster0_df = cluster0.to_df()
cluster1_df = cluster1.to_df()

# %%
cluster0_df
# Out:
#                    TNFRSF4    CPSF3L    ATAD3C   C1orf86      RER1  TNFRSF25  \
# AAACATACAACCAC-1 -0.171470 -0.280812 -0.046677 -0.475169 -0.544024  4.928497
# AAACATTGATCAGC-1 -0.376888 -0.295085 -0.057527 -0.520972  1.332648 -0.309362
# AAACCGTGTATGCG-1 -0.256484 -0.220394 -0.046800 -0.345859 -0.333409 -0.208122
# AAACGCACTGGTAC-1 -0.271255 -0.264511 -0.050418 -0.445480 -0.492662 -0.252299
# AAACGCTGACCAGT-1 -0.095658 -0.276485 -0.042734 -0.460367 -0.523118 -0.214493
# ...                    ...       ...       ...       ...       ...       ...
# TTTAGCTGATACCG-1 -0.245611 -0.288717 -0.050774 -0.497855 -0.577641 -0.267181
# TTTCACGAGGTTCA-1 -0.293487 -0.258213 -0.051076 -0.432904  1.942467 -0.252741
# TTTCAGTGGAAGGC-1 -0.266890 -0.250201 -0.049265  2.345041 -0.441035 -0.238087
# TTTCCAGAGGTGAG-1 -0.352371  3.470952 -0.054041 -0.441120 -0.482631 -0.270786
# TTTGCATGCCTCAC-1 -0.333789 -0.253588 -0.052716 -0.425292 -0.457937  5.322872
#
# ...

# %%
cluster1_df
# Out:
#                    TNFRSF4    CPSF3L    ATAD3C   C1orf86      RER1  TNFRSF25  \
# AAACCGTGCTTCCG-1 -0.285241 -0.281735 -0.052227 -0.484929  1.572680 -0.271825
# AAACGCTGTTTCTG-1 -0.124531 -0.233736 -0.041312 -0.366757 -0.371873 -0.183660
# AAAGAGACGCGAGA-1 -0.328780 -0.293895 -0.055128 -0.515058  1.378630 -0.294944
# AAAGCAGATATCGG-1 -0.397113 -0.348524 -0.062022 -0.641801  1.478928 -0.363521
# AAAGTTTGTAGCGT-1 -0.225407 -0.287336 -0.049709 -0.493402 -0.571253 -0.260325
# ...                    ...       ...       ...       ...       ...       ...
# TTTAGGCTCCTTTA-1 -0.209613 -0.261618 -0.047253  3.077668 -0.477904 -0.232580
# TTTATCCTGTTGTG-1 -0.365757 -0.316090 -0.058374 -0.567175 -0.684342 -0.325360
# TTTCAGTGTCTATC-1 -0.153954 -0.225480 -0.042188 -0.350291 -0.344358 -0.184316
# TTTCGAACACCTGA-1 -0.399291 -0.343465 -0.061794 -0.630639  0.814203 -0.359529
# TTTCGAACTCTCAT-1 -0.290368  2.638308 -0.054510 -0.554384 -0.666646 -0.301333
#
# ...

# %%
cluster0_df.to_csv('cluster0.csv')
cluster1_df.to_csv('cluster1.csv')

# %%
adata.to_df().to_csv('adata.csv')

# %%
cluster0_df.to_hdf('cluster0.h5', key = 'df')
cluster1_df.to_hdf('cluster1.h5', key = 'df')
adata.to_df().to_hdf('adata.h5', key = 'df')

# %%
adata.to_df()
# Out:
#                    TNFRSF4    CPSF3L    ATAD3C   C1orf86      RER1  TNFRSF25  \
# AAACATACAACCAC-1 -0.171470 -0.280812 -0.046677 -0.475169 -0.544024  4.928497
# AAACATTGAGCTAC-1 -0.214582 -0.372653 -0.054804 -0.683391  0.633951 -0.334837
# AAACATTGATCAGC-1 -0.376888 -0.295085 -0.057527 -0.520972  1.332648 -0.309362
# AAACCGTGCTTCCG-1 -0.285241 -0.281735 -0.052227 -0.484929  1.572680 -0.271825
# AAACCGTGTATGCG-1 -0.256484 -0.220394 -0.046800 -0.345859 -0.333409 -0.208122
# ...                    ...       ...       ...       ...       ...       ...
# TTTCGAACTCTCAT-1 -0.290368  2.638308 -0.054510 -0.554384 -0.666646 -0.301333
# TTTCTACTGAGGCA-1 -0.386344  2.652699 -0.058686 -0.545443  1.201866 -0.321670
# TTTCTACTTCCTCG-1 -0.207090 -0.250464 -0.046397 -0.409737  2.193954 -0.221747
# TTTGCATGAGAGGC-1 -0.190328 -0.226334 -0.043999 -0.354661 -0.350005 -0.195177
# TTTGCATGCCTCAC-1 -0.333789 -0.253588 -0.052716 -0.425292 -0.457937  5.322872
#
# ...
